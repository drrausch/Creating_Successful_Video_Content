# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd

# %%
df = pd.read_csv('rt.movie_info_info.tsv', sep='\t', error_bad_lines=False)
df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
df.tail()
# Out:
#         id                                           synopsis rating  \
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
df.isna().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
df.dropna(subset=['box_office'])
# Out:
#         id                                           synopsis rating  \
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 6       10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7       13  Stewart Kane, an Irishman living in the Austra...      R
# 8       14  "Love Ranch" is a bittersweet love story that ...      R
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# ...    ...                                                ...    ...
# 1541  1980  A band of renegades on the run in outer space ...  PG-13
# 1542  1981  Money, Fame and the Knowledge of English. In I...     NR
# 1545  1985  A woman who joins the undead against her will ...      R
# 1546  1986  Aki Kaurismaki's The Man Without a Past opens ...     PG
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
#
#                                                  genre             director  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
df_rt_edit = df.dropna(subset=['box_office'])

# %%
df_rt_edit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 340 entries, 1 to 1555
# Data columns (total 12 columns):
# id              340 non-null int64
# synopsis        340 non-null object
# rating          340 non-null object
# genre           340 non-null object
# director        299 non-null object
# writer          273 non-null object
# theater_date    334 non-null object
# dvd_date        334 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         338 non-null object
# studio          305 non-null object
# dtypes: int64(1), object(11)
# memory usage: 34.5+ KB

# %% [markdown]
# # rt.movie_info_info.tsv

# %%
df_reviews = pd.read_csv('rt.reviews.tsv', sep='\t', error_bad_lines=False, encoding='latin1')
df_reviews.head(15)
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1    3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2    3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3    3  Continuing along a line introduced in last yea...    NaN   fresh
# 4    3             ... a perverse twist on neorealism...     NaN   fresh
# 5    3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 8    3  Cronenberg's cold, exacting precision and emot...    NaN   fresh
# 9    3  Over and above its topical urgency or the bit ...    NaN   fresh
# 10   3  Cosmopolis" is a hypnotic examination of our m...    NaN   fresh
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
# id            54432 non-null int64
# review        48869 non-null object
# rating        40915 non-null object
# fresh         54432 non-null object
# critic        51710 non-null object
# top_critic    54432 non-null int64
# publisher     54123 non-null object
# date          54432 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
df_reviews.columns
# Out:
# Index(['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')

# %%
df_reviews.isna().sum()
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %%
df_reviews.tail(15)
# Out:
#          id                                             review rating   fresh  \
# 54417  2000  The funny thing is, I didn't mind all this con...    NaN   fresh
# 54418  2000  Slight, but colorful and forward-moving... Was...     C+   fresh
# 54419  2000            Sleek, shallow, but frequently amusing.  2.5/4   fresh
# 54420  2000  The spaniel-eyed Jean Reno infuses Hubert with...    3/4   fresh
# 54421  2000  Manages to be somewhat well-acted, not badly a...  1.5/4  rotten
# 54422  2000  Arguably the best script that Besson has writt...  3.5/5   fresh
# 54423  2000          Despite the title, Wasabi isn't so spicy.      C  rotten
# 54424  2000  Dawdles and drags when it should pop; it doesn...  1.5/5  rotten
# 54425  2000  Despite Besson's high-profile name being Wasab...    NaN   fresh
# 54426  2000  The film lapses too often into sugary sentimen...    NaN  rotten
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# ...

# %%
df_reviews_edit = df_reviews.dropna(subset=['rating'])

# %%
df_reviews_edit.head(15)
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 12   3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# 13   3  The anger over the injustice of the financial ...      B   fresh
# 14   3  For those who like their Cronenberg thick and ...    3/4   fresh
# 15   3  For better or worse - often both - Cosmopolis ...    3/5   fresh
# 16   3  For one of the smartest films I've seen in a w...    4/5   fresh
# 17   3      Its major problem is that it's not cinematic.      B   fresh
# 18   3  It's fascinating to watch Pattinson actually a...    2/4  rotten
# 19   3  A black comedy as dry and deadpan as a bleache...    4/4   fresh
# ...

# %%
df_reviews_edit.tail(15)
# Out:
#          id                                             review rating   fresh  \
# 54413  2000  Wasabi does its job colorfully and entertainin...     C+   fresh
# 54414  2000  A cheerful enough but imminently forgettable r...  2.5/4  rotten
# 54415  2000                             Fluffy and disposible.  2.5/5  rotten
# 54416  2000  One minute, you think you're watching a seriou...    2/4  rotten
# 54418  2000  Slight, but colorful and forward-moving... Was...     C+   fresh
# 54419  2000            Sleek, shallow, but frequently amusing.  2.5/4   fresh
# 54420  2000  The spaniel-eyed Jean Reno infuses Hubert with...    3/4   fresh
# 54421  2000  Manages to be somewhat well-acted, not badly a...  1.5/4  rotten
# 54422  2000  Arguably the best script that Besson has writt...  3.5/5   fresh
# 54423  2000          Despite the title, Wasabi isn't so spicy.      C  rotten
# 54424  2000  Dawdles and drags when it should pop; it doesn...  1.5/5  rotten
# ...

# %% [markdown]
# # Summary of Rotten Tomatos
#
# ## rt.movie_info_info.tsv
#
# This data set has alot of NaN. Initially you start off with having 1560 rows but as you can see from the orginial df there is only 340 results of the the series "box office".
# I was thinking we could use the 340 results and join them with the other df from the other data sets.
# However, 'box_office' has a data type of objects and I think it would be best if we convert all of that in int. I am not sure if this is right but I pretty sure we will have problems creating visuals if we choose to leave it as objects
#
# ## rt.movie_reviews.tsv
#
# This data set is pretty confusing, have to think of a way to reformat rating.
#
# ## Steps to take 9/26/20
#
#  * Look into the other data set that is also part of the rt
#  * Convert the data types: change objects into int
#  * Look into the last data set to see if I can clean that and see if we can use something that is Useful
